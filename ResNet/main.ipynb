# %%
import backend
import torch
from torchsummary import summary


resnet = backend.ResNet(in_channels=3).cuda()

summary(resnet, (3, 224, 224))

# %%
deep_resnet = backend.DeepResNet(in_channels=3).cuda()

summary(deep_resnet, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 112, 112]           9,472
#          MaxPool2d-2           [-1, 64, 55, 55]               0
#             Conv2d-3           [-1, 64, 55, 55]           4,160
#               ReLU-4           [-1, 64, 55, 55]               0
#             Conv2d-5           [-1, 64, 28, 28]          36,928
#               ReLU-6           [-1, 64, 28, 28]               0
#             Conv2d-7          [-1, 256, 28, 28]          16,640
#             Conv2d-8          [-1, 256, 28, 28]          16,640
#               ReLU-9          [-1, 256, 28, 28]               0
# BottleneckResidualBlock-10          [-1, 256, 28, 28]               0
#            Conv2d-11           [-1, 64, 28, 28]          16,448
#              ReLU-12           [-1, 64, 28, 28]               0
#            Conv2d-13           [-1, 64, 14, 14]          36,928
# ...
